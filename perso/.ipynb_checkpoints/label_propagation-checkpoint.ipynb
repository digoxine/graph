# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from scipy.cluster.vq import kmeans,vq
import random

# %%
G = nx.Graph()
f = open('../Datas/label_propagation_res/label_propagation_400_p_.500_q_.036_nodes.res', 'r')
cpt = 0
for line in f:
    lis = line.split() 
    print(lis[1])
    G.add_node((int) (cpt),group=(int)(lis[1]))
    cpt+=1
f.close()
# Out:
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 54
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 134
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 227
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 289
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 313
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361
# 361

# %%
#Attribution de pos
position = []
labels = []
MAX_X = 1500
MAX_Y = 1500
NB_CLUSTERS = 8
NB_NODES = 400
cpt = 0
NB_X = NB_CLUSTERS//2
NB_Y = NB_CLUSTERS - NB_X
GRILLE_X = (MAX_X) //(NB_X)
GRILLE_Y = (MAX_Y) // NB_Y
f = open('../Datas/label_propagation_res/label_propagation_400_p_.500_q_.036_nodes.res', 'r')
for line in f:
    current_cluster = (int) ( cpt/ (NB_NODES/NB_CLUSTERS) )
    labels.append(current_cluster)
    current_nb_x = (current_cluster//NB_X)
    current_nb_y = (current_cluster%NB_X)
    x = random.randint((current_nb_x)*GRILLE_X,(current_nb_x+1)*GRILLE_X)
    y = random.randint((current_nb_y)*GRILLE_Y,(current_nb_y+1)*GRILLE_Y)
    position.append((x,y))
    cpt+=1
f.close()

# %%
position
# Out:
# [(244, 50),
#  (62, 131),
#  (52, 5),
#  (285, 253),
#  (32, 6),
#  (322, 241),
#  (124, 266),
#  (216, 70),
#  (71, 250),
#  (267, 144),
#  (174, 328),
#  (16, 122),
#  (252, 52),
#  (367, 216),
#  (85, 136),
#  (139, 239),
#  (329, 340),
#  (332, 91),
#  (12, 140),
#  (246, 20),
#  (221, 74),
#  (48, 222),
#  (272, 252),
#  (205, 319),
#  (172, 223),
#  (64, 370),
#  (317, 24),
#  (137, 347),
#  (293, 273),
#  (35, 169),
#  (358, 135),
#  (46, 295),
#  (148, 160),
#  (114, 334),
#  (74, 74),
#  (356, 213),
#  (180, 287),
#  (75, 102),
#  (142, 280),
#  (265, 158),
#  (308, 357),
#  (315, 176),
#  (345, 291),
#  (99, 156),
#  (232, 41),
#  (284, 166),
#  (10, 205),
#  (234, 173),
#  (23, 55),
#  (112, 22),
#  (225, 533),
#  (91, 423),
#  (112, 439),
#  (176, 643),
#  (178, 417),
#  (93, 376),
#  (100, 522),
#  (132, 673),
#  (201, 464),
#  (11, 473),
#  (75, 684),
#  (340, 517),
#  (237, 533),
#  (352, 629),
#  (162, 571),
#  (191, 701),
#  (337, 663),
#  (337, 515),
#  (183, 647),
#  (204, 673),
#  (179, 375),
#  (4, 575),
#  (344, 578),
#  (302, 542),
#  (305, 407),
#  (319, 507),
#  (321, 663),
#  (84, 631),
#  (93, 544),
#  (343, 715),
#  (107, 384),
#  (294, 726),
#  (158, 693),
#  (364, 724),
#  (3, 615),
#  (79, 725),
#  (119, 533),
#  (360, 398),
#  (164, 455),
#  (87, 539),
#  (351, 418),
#  (175, 469),
#  (226, 379),
#  (282, 676),
#  (146, 466),
#  (135, 723),
#  (350, 587),
#  (291, 392),
#  (141, 385),
#  (168, 598),
#  (354, 784),
#  (314, 838),
#  (357, 940),
#  (374, 1105),
#  (148, 1087),
#  (334, 1100),
#  (284, 891),
#  (73, 1019),
#  (326, 1078),
#  (555, 541),
#  (529, 703),
#  (425, 536),
#  (651, 681),
#  (737, 625),
#  (420, 542),
#  (710, 387),
#  (405, 402),
#  (670, 443),
#  (407, 543),
#  (388, 403),
#  (627, 409),
#  (626, 550),
#  (670, 398),
#  (737, 581),
#  (534, 699),
#  (461, 497),
#  (448, 405),
#  (495, 591),
#  (444, 657),
#  (412, 639),
#  (540, 633),
#  (543, 1040),
#  (535, 884),
#  (554, 960),
#  (548, 815),
#  (740, 814),
#  (554, 999),
#  (743, 837),
#  (435, 766),
#  (386, 797),
#  (750, 898),
#  (477, 932),
#  (664, 768),
#  (520, 825),
#  (375, 946),
#  (502, 804),
#  (626, 887),
#  (376, 956),
#  (509, 909),
#  (394, 1068),
#  (601, 1057),
#  (499, 992),
#  (544, 864),
#  (670, 936),
#  (743, 1071),
#  (508, 802),
#  (652, 1007),
#  (472, 1079),
#  (468, 907),
#  (724, 780),
#  (637, 801),
#  (616, 1060),
#  (558, 1013),
#  (566, 889),
#  (598, 1060),
#  (627, 1072),
#  (433, 1115),
#  (582, 981),
#  (737, 971),
#  (581, 866),
#  (565, 895),
#  (385, 1019),
#  (455, 873),
#  (623, 945),
#  (522, 822),
#  (616, 874),
#  (650, 823),
#  (668, 1081),
#  (613, 1086),
#  (621, 952),
#  (729, 1044),
#  (458, 1444),
#  (678, 1455),
#  (676, 1485),
#  (521, 1185),
#  (624, 1324),
#  (631, 1133),
#  (641, 1180),
#  (554, 1300),
#  (520, 1355),
#  (560, 1295),
#  (621, 1416),
#  (646, 1490),
#  (685, 1375),
#  (391, 1445),
#  (407, 1177),
#  (609, 1155),
#  (621, 1284),
#  (655, 1235),
#  (732, 1377),
#  (423, 1195),
#  (537, 1272),
#  (704, 1153),
#  (725, 1130),
#  (643, 1478),
#  (517, 1370),
#  (518, 1373),
#  (666, 1291),
#  (445, 1176),
#  (587, 1418),
#  (531, 1151),
#  (573, 1477),
#  (719, 1322),
#  (519, 1173),
#  (489, 1498),
#  (625, 1278),
#  (745, 1478),
#  (709, 1391),
#  (692, 1300),
#  (638, 1326),
#  (584, 1458),
#  (391, 1450),
#  (440, 1497),
#  (544, 1374),
#  (526, 1254),
#  (501, 1324),
#  (550, 1244),
#  (496, 1395),
#  (628, 1169),
#  (726, 1332),
#  (415, 1176)]

# %%
labels = {}
labels[0] = r'$a$'
labels[1] = r'$b$'
labels[2] = r'$c$'
labels[3] = r'$d$'
labels[4] = r'$\alpha$'
labels[5] = r'$\beta$'
labels[6] = r'$\gamma$'
labels[7] = r'$\delta$'
plt.plot()
nx.draw_networkx_labels(G, position, labels, font_size=16)
plt.axis('off')
plt.show()

# %%
from itertools import count
groups = set(nx.get_node_attributes(G, 'group').values())
mapping = dict(zip(sorted(groups),count()))
nodes = G.nodes()
colors = [mapping[G.nodes[n]['group']] for n in nodes]
nc = nx.draw_networkx_nodes(G,position,nodelist=nodes, node_color=colors, with_labels=False, node_size=100, cmap=plt.cm.jet)
plt.colorbar(nc)
plt.savefig("../Datas/colorLabelPropagation036.png")
plt.axis('off')
plt.show()

# %%
#Position

# %%
G = nx.Graph()
f = open('../Datas/label_propagation_res/label_propagation_400_p_.500_q_.040_nodes.res', 'r')
cpt = 0
for line in f:
    lis = line.split() 
    G.add_node((int) (cpt),group=(int)(lis[1]))
    cpt+=1
f.close()
#Attribution de pos
position = []
labels = []
MAX_X = 1500
MAX_Y = 1500
NB_CLUSTERS = 8
NB_NODES = 400
cpt = 0
NB_X = NB_CLUSTERS//2
NB_Y = NB_CLUSTERS - NB_X
GRILLE_X = (MAX_X) //(NB_X)
GRILLE_Y = (MAX_Y) // NB_Y
f = open('../Datas/label_propagation_res/label_propagation_400_p_.500_q_.040_nodes.res', 'r')
for line in f:
    current_cluster = (int) ( cpt/ (NB_NODES/NB_CLUSTERS) )
    labels.append(current_cluster)
    current_nb_x = (current_cluster//NB_X)
    current_nb_y = (current_cluster%NB_X)
    x = random.randint((current_nb_x)*GRILLE_X,(current_nb_x+1)*GRILLE_X)
    y = random.randint((current_nb_y)*GRILLE_Y,(current_nb_y+1)*GRILLE_Y)
    position.append((x,y))
    cpt+=1
f.close()
from itertools import count
groups = set(nx.get_node_attributes(G, 'group').values())
mapping = dict(zip(sorted(groups),count()))
nodes = G.nodes()
colors = [mapping[G.nodes[n]['group']] for n in nodes]
nc = nx.draw_networkx_nodes(G,position,nodelist=nodes, node_color=colors, with_labels=False, node_size=100, cmap=plt.cm.jet)
plt.colorbar(nc)
plt.savefig("../Datas/colorLabelPropagation040.png")
plt.axis('off')
plt.show()

# %%
G = nx.Graph()
f = open('../Datas/label_propagation_res/louvain_400_p_.500_q_.004', 'r')
cpt = 0
for line in f:
    lis = line.split() 
    G.add_node((int) (cpt),group=(int)(lis[1]))
    cpt+=1
f.close()
#Attribution de pos
position = []
labels = []
MAX_X = 1500
MAX_Y = 1500
NB_CLUSTERS = 8
NB_NODES = 400
cpt = 0
NB_X = NB_CLUSTERS//2
NB_Y = NB_CLUSTERS - NB_X
GRILLE_X = (MAX_X) //(NB_X)
GRILLE_Y = (MAX_Y) // NB_Y
f = open('../Datas/label_propagation_res/louvain_400_p_.500_q_.004', 'r')
for line in f:
    current_cluster = (int) ( cpt/ (NB_NODES/NB_CLUSTERS) )
    labels.append(current_cluster)
    current_nb_x = (current_cluster//NB_X)
    current_nb_y = (current_cluster%NB_X)
    x = random.randint((current_nb_x)*GRILLE_X,(current_nb_x+1)*GRILLE_X)
    y = random.randint((current_nb_y)*GRILLE_Y,(current_nb_y+1)*GRILLE_Y)
    position.append((x,y))
    cpt+=1
f.close()
from itertools import count
groups = set(nx.get_node_attributes(G, 'group').values())
mapping = dict(zip(sorted(groups),count()))
nodes = G.nodes()
colors = [mapping[G.nodes[n]['group']] for n in nodes]
nc = nx.draw_networkx_nodes(G,position,nodelist=nodes, node_color=colors, with_labels=False, node_size=100, cmap=plt.cm.jet)
plt.colorbar(nc)
plt.savefig("../Datas/colorLouvain040.png")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-b6e2e984b0ed> in <module>
#       1 G = nx.Graph()
# ----> 2 f = open('../Datas/label_propagation_res/louvain_400_p_.500_q_.004_nodes.res', 'r')
#       3 cpt = 0
#       4 for line in f:
#       5     lis = line.split()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Datas/label_propagation_res/louvain_400_p_.500_q_.004_nodes.res'
